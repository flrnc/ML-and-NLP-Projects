# %%
import re
import nltk
import pandas as pd
from string import punctuation
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
pd.set_option('display.max_colwidth',50)
data = pd.read_csv("hp_script.csv")
data.head()
# Out:
#    ID_number  scene      character_name  \
# 0          1      1    Albus Dumbledore
# 1          2      1  Minerva McGonagall
# 2          3      1    Albus Dumbledore
# 3          4      1  Minerva McGonagall
# 4          5      1    Albus Dumbledore
#
#                                             dialogue
# 0  I should have known that you would be here, Pr...
# 1  Good evening, Professor Dumbledore. Are the ru...
# 2   I'm afraid so, Professor. The good, and the bad.
# 3                                       And the boy?
# 4                            Hagrid is bringing him.

# %%
data= data[['character_name','dialogue']]
data.head()
# Out:
#        character_name                                           dialogue
# 0    Albus Dumbledore  I should have known that you would be here, Pr...
# 1  Minerva McGonagall  Good evening, Professor Dumbledore. Are the ru...
# 2    Albus Dumbledore   I'm afraid so, Professor. The good, and the bad.
# 3  Minerva McGonagall                                       And the boy?
# 4    Albus Dumbledore                            Hagrid is bringing him.

# %%
print(f' Input data has {len(data)} rows, {len,(data.columns)} columns')
# Out:
#  Input data has 793 rows, (<built-in function len>, Index(['character_name', 'dialogue'], dtype='object')) columns

# %% [markdown]
# ### Text Cleaning

# %%
def remove_punctuation(data):
    txt_nopunct = [c for c in data if c not in punctuation]
    return txt_nopunct

# %%
data['clean'] = data['dialogue'].apply(lambda x: remove_punctuation(x))
data.head(10)
# Out:
#        character_name                                           dialogue  \
# 0    Albus Dumbledore  I should have known that you would be here, Pr...
# 1  Minerva McGonagall  Good evening, Professor Dumbledore. Are the ru...
# 2    Albus Dumbledore   I'm afraid so, Professor. The good, and the bad.
# 3  Minerva McGonagall                                       And the boy?
# 4    Albus Dumbledore                            Hagrid is bringing him.
# 5  Minerva McGonagall  Do you think it wise to trust Hagrid with some...
# 6    Albus Dumbledore  Ah, Professor, I would trust Hagrid with my life.
# 7       Rubeus Hagrid   Professor Dumbledore, Sir. Professor McGonagall.
# 8    Albus Dumbledore                      No problems, I trust, Hagrid?
# 9       Rubeus Hagrid  No, Sir. Little tyke fell asleep just as we we...
#
#                                                clean
# 0  [I,  , s, h, o, u, l, d,  , h, a, v, e,  , k, ...
# 1  [G, o, o, d,  , e, v, e, n, i, n, g,  , P, r, ...
# 2  [I, m,  , a, f, r, a, i, d,  , s, o,  , P, r, ...
# 3                  [A, n, d,  , t, h, e,  , b, o, y]
# 4  [H, a, g, r, i, d,  , i, s,  , b, r, i, n, g, ...
# 5  [D, o,  , y, o, u,  , t, h, i, n, k,  , i, t, ...
# 6  [A, h,  , P, r, o, f, e, s, s, o, r,  , I,  , ...
# 7  [P, r, o, f, e, s, s, o, r,  , D, u, m, b, l, ...
# 8  [N, o,  , p, r, o, b, l, e, m, s,  , I,  , t, ...
# 9  [N, o,  , S, i, r,  , L, i, t, t, l, e,  , t, ...

# %%
def remove_punctuation(data):
    txt_nopunct = "".join([c for c in data if c not in punctuation])
    return txt_nopunct

# %%
data['clean'] = data['dialogue'].apply(lambda x: remove_punctuation(x))
data.head()
# Out:
#        character_name                                           dialogue  \
# 0    Albus Dumbledore  I should have known that you would be here, Pr...
# 1  Minerva McGonagall  Good evening, Professor Dumbledore. Are the ru...
# 2    Albus Dumbledore   I'm afraid so, Professor. The good, and the bad.
# 3  Minerva McGonagall                                       And the boy?
# 4    Albus Dumbledore                            Hagrid is bringing him.
#
#                                                clean
# 0  I should have known that you would be here Pro...
# 1  Good evening Professor Dumbledore Are the rumo...
# 2        Im afraid so Professor The good and the bad
# 3                                        And the boy
# 4                             Hagrid is bringing him

# %%
def tokenize(txt):
    tokens = re.split('\W+', txt)
    return tokens

data['tokenize'] = data['clean'].apply(lambda x: tokenize(x.lower()))
data.head()
# Out:
#        character_name                                           dialogue  \
# 0    Albus Dumbledore  I should have known that you would be here, Pr...
# 1  Minerva McGonagall  Good evening, Professor Dumbledore. Are the ru...
# 2    Albus Dumbledore   I'm afraid so, Professor. The good, and the bad.
# 3  Minerva McGonagall                                       And the boy?
# 4    Albus Dumbledore                            Hagrid is bringing him.
#
#                                                clean  \
# 0  I should have known that you would be here Pro...
# 1  Good evening Professor Dumbledore Are the rumo...
# 2        Im afraid so Professor The good and the bad
# 3                                        And the boy
# 4                             Hagrid is bringing him
#
#                                             tokenize
# 0  [i, should, have, known, that, you, would, be,...
# 1  [good, evening, professor, dumbledore, are, th...
# 2  [im, afraid, so, professor, the, good, and, th...
# 3                                    [and, the, boy]
# 4                        [hagrid, is, bringing, him]

# %% [markdown]
# ### Remove Stop Words

# %%
stopwords = nltk.corpus.stopwords.words('english')

def remove_stopwords(cleaned):
    txt_clean = [word for word in cleaned if word not in stopwords]
    return txt_clean

data['stop words'] = data['tokenize'].apply(lambda x: remove_stopwords(x))
data.tail()
# Out:
#        character_name                                           dialogue  \
# 788     Rubeus Hagrid  Go on. On with you, on with you now. Oh, now l...
# 789      Harry Potter  But Hagrid, we're not allowed to do magic away...
# 790     Rubeus Hagrid     I do, but your cousin don't, do he? Eh? Hmmhmm
# 791  Hermione Granger        Feels strange to be going home, doesn't it?
# 792      Harry Potter                    I'm not going home, not really.
#
#                                                  clean  \
# 788  Go on On with you on with you now Oh now liste...
# 789  But Hagrid were not allowed to do magic away f...
# 790          I do but your cousin dont do he Eh Hmmhmm
# 791           Feels strange to be going home doesnt it
# 792                       Im not going home not really
#
#                                               tokenize  \
# 788  [go, on, on, with, you, on, with, you, now, oh...
# 789  [but, hagrid, were, not, allowed, to, do, magi...
# 790  [i, do, but, your, cousin, dont, do, he, eh, h...
# 791  [feels, strange, to, be, going, home, doesnt, it]
# 792                [im, not, going, home, not, really]
#
#                                             stop words
# 788  [go, oh, listen, harry, dope, cousin, dudley, ...
# 789     [hagrid, allowed, magic, away, hogwarts, know]
# 790                         [cousin, dont, eh, hmmhmm]
# 791              [feels, strange, going, home, doesnt]
# 792                          [im, going, home, really]

# %% [markdown]
# ### Porter Stemming

# %%
ps = PorterStemmer()

def stemming(tokenized):
    text = [ps.stem(word) for word in tokenized]
    return text

# %%
data['stemmed'] = data['stop words'].apply(lambda x: stemming(x))
data.tail(10)
# Out:
#        character_name                                           dialogue  \
# 783     Rubeus Hagrid  Come on now, hurry up, you'll be late! Train's...
# 784  Hermione Granger                                    Come on, Harry.
# 785      Harry Potter                                        One minute.
# 786     Rubeus Hagrid  Thought you were leaving without sayin' goodby...
# 787      Harry Potter                                    Thanks, Hagrid.
# 788     Rubeus Hagrid  Go on. On with you, on with you now. Oh, now l...
# 789      Harry Potter  But Hagrid, we're not allowed to do magic away...
# 790     Rubeus Hagrid     I do, but your cousin don't, do he? Eh? Hmmhmm
# 791  Hermione Granger        Feels strange to be going home, doesn't it?
# 792      Harry Potter                    I'm not going home, not really.
#
#                                                  clean  \
# 783  Come on now hurry up youll be late Trains leav...
# 784                                      Come on Harry
# 785                                         One minute
# 786  Thought you were leaving without sayin goodbye...
# 787                                      Thanks Hagrid
# 788  Go on On with you on with you now Oh now liste...
# 789  But Hagrid were not allowed to do magic away f...
# 790          I do but your cousin dont do he Eh Hmmhmm
# 791           Feels strange to be going home doesnt it
# 792                       Im not going home not really
#
#                                               tokenize  \
# 783  [come, on, now, hurry, up, youll, be, late, tr...
# 784                                  [come, on, harry]
# 785                                      [one, minute]
# 786  [thought, you, were, leaving, without, sayin, ...
# 787                                   [thanks, hagrid]
# 788  [go, on, on, with, you, on, with, you, now, oh...
# 789  [but, hagrid, were, not, allowed, to, do, magi...
# 790  [i, do, but, your, cousin, dont, do, he, eh, h...
# 791  [feels, strange, to, be, going, home, doesnt, it]
# 792                [im, not, going, home, not, really]
#
#                                             stop words  \
# 783  [come, hurry, youll, late, trains, leaving, go...
# 784                                      [come, harry]
# 785                                      [one, minute]
# 786  [thought, leaving, without, sayin, goodbye, ya, ]
# 787                                   [thanks, hagrid]
# 788  [go, oh, listen, harry, dope, cousin, dudley, ...
# 789     [hagrid, allowed, magic, away, hogwarts, know]
# 790                         [cousin, dont, eh, hmmhmm]
# 791              [feels, strange, going, home, doesnt]
# 792                          [im, going, home, really]
#
#                                                stemmed
# 783  [come, hurri, youll, late, train, leav, go, co...
# 784                                      [come, harri]
# 785                                       [one, minut]
# 786      [thought, leav, without, sayin, goodby, ya, ]
# 787                                    [thank, hagrid]
# 788  [go, oh, listen, harri, dope, cousin, dudley, ...
# 789        [hagrid, allow, magic, away, hogwart, know]
# 790                         [cousin, dont, eh, hmmhmm]
# 791                   [feel, strang, go, home, doesnt]
# 792                             [im, go, home, realli]

# %%
words = data['stop words'][1:7]
words
# Out:
# 1    [good, evening, professor, dumbledore, rumours...
# 2                   [im, afraid, professor, good, bad]
# 3                                                [boy]
# 4                                   [hagrid, bringing]
# 5    [think, wise, trust, hagrid, something, import...
# 6          [ah, professor, would, trust, hagrid, life]
# Name: stop words, dtype: object

# %% [markdown]
# ### Stemming and Lemmatization

# %%
lemmatizer = WordNetLemmatizer()

for y in words:
    for w in y: 
        print("\n\n"+w, "\nSTEMMING :", ps.stem(w),"\n","LEMMATIZATION :", lemmatizer.lemmatize(w,pos = "n"))
# Out:
# good
# STEMMING : good
#  LEMMATIZATION : good
#
#
# evening
# STEMMING : even
#  LEMMATIZATION : evening
#
#
# professor
# STEMMING : professor
#  LEMMATIZATION : professor
#
#
# dumbledore
# STEMMING : dumbledor
#  LEMMATIZATION : dumbledore
#
#
# rumours
# STEMMING : rumour
#  LEMMATIZATION : rumour
#
#
# true
# STEMMING : true
#  LEMMATIZATION : true
#
#
# albus
# STEMMING : albu
#  LEMMATIZATION : albus
#
#
# im
# STEMMING : im
#  LEMMATIZATION : im
#
#
# afraid
# STEMMING : afraid
#  LEMMATIZATION : afraid
#
#
# professor
# STEMMING : professor
#  LEMMATIZATION : professor
#
#
# good
# STEMMING : good
#  LEMMATIZATION : good
#
#
# bad
# STEMMING : bad
#  LEMMATIZATION : bad
#
#
# boy
# STEMMING : boy
#  LEMMATIZATION : boy
#
#
# hagrid
# STEMMING : hagrid
#  LEMMATIZATION : hagrid
#
#
# bringing
# STEMMING : bring
#  LEMMATIZATION : bringing
#
#
# think
# STEMMING : think
#  LEMMATIZATION : think
#
#
# wise
# STEMMING : wise
#  LEMMATIZATION : wise
#
#
# trust
# STEMMING : trust
#  LEMMATIZATION : trust
#
#
# hagrid
# STEMMING : hagrid
#  LEMMATIZATION : hagrid
#
#
# something
# STEMMING : someth
#  LEMMATIZATION : something
#
#
# important
# STEMMING : import
#  LEMMATIZATION : important
#
#
# ah
# STEMMING : ah
#  LEMMATIZATION : ah
#
#
# professor
# STEMMING : professor
#  LEMMATIZATION : professor
#
#
# would
# STEMMING : would
#  LEMMATIZATION : would
#
#
# trust
# STEMMING : trust
#  LEMMATIZATION : trust
#
#
# hagrid
# STEMMING : hagrid
#  LEMMATIZATION : hagrid
#
#
# life
# STEMMING : life
#  LEMMATIZATION : life

# %%
#without pos
for y in words:
    for w in y: 
         print("\n\n"+w, "\nSTEMMING :", ps.stem(w),"\n","LEMMATIZATION :", lemmatizer.lemmatize(w))
# Out:
# good
# STEMMING : good
#  LEMMATIZATION : good
#
#
# evening
# STEMMING : even
#  LEMMATIZATION : evening
#
#
# professor
# STEMMING : professor
#  LEMMATIZATION : professor
#
#
# dumbledore
# STEMMING : dumbledor
#  LEMMATIZATION : dumbledore
#
#
# rumours
# STEMMING : rumour
#  LEMMATIZATION : rumour
#
#
# true
# STEMMING : true
#  LEMMATIZATION : true
#
#
# albus
# STEMMING : albu
#  LEMMATIZATION : albus
#
#
# im
# STEMMING : im
#  LEMMATIZATION : im
#
#
# afraid
# STEMMING : afraid
#  LEMMATIZATION : afraid
#
#
# professor
# STEMMING : professor
#  LEMMATIZATION : professor
#
#
# good
# STEMMING : good
#  LEMMATIZATION : good
#
#
# bad
# STEMMING : bad
#  LEMMATIZATION : bad
#
#
# boy
# STEMMING : boy
#  LEMMATIZATION : boy
#
#
# hagrid
# STEMMING : hagrid
#  LEMMATIZATION : hagrid
#
#
# bringing
# STEMMING : bring
#  LEMMATIZATION : bringing
#
#
# think
# STEMMING : think
#  LEMMATIZATION : think
#
#
# wise
# STEMMING : wise
#  LEMMATIZATION : wise
#
#
# trust
# STEMMING : trust
#  LEMMATIZATION : trust
#
#
# hagrid
# STEMMING : hagrid
#  LEMMATIZATION : hagrid
#
#
# something
# STEMMING : someth
#  LEMMATIZATION : something
#
#
# important
# STEMMING : import
#  LEMMATIZATION : important
#
#
# ah
# STEMMING : ah
#  LEMMATIZATION : ah
#
#
# professor
# STEMMING : professor
#  LEMMATIZATION : professor
#
#
# would
# STEMMING : would
#  LEMMATIZATION : would
#
#
# trust
# STEMMING : trust
#  LEMMATIZATION : trust
#
#
# hagrid
# STEMMING : hagrid
#  LEMMATIZATION : hagrid
#
#
# life
# STEMMING : life
#  LEMMATIZATION : life
